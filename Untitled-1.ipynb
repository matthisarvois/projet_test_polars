# %%
import polars as pl  
df_pl = pl.read_csv("data/aapl_master_enriched.csv")

for i in range(100):
    df_pd = pl.concat([df_pd,df_pd],axis=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 import polars as pl
#       3 for i in range(100):
# ----> 4     df_pd = pl.concat([df_pd,df_pd],axis=0)
#
# NameError: name 'df_pd' is not defined
